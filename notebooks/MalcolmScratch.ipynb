# %%
import datacleaning as dc
import linregvis as lrv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statsmodels.api as sm
import scipy.stats as stats
from statsmodels.formula.api import ols
from sklearn.model_selection import train_test_split 
from sklearn.dummy import DummyRegressor
from statsmodels.graphics.regressionplots import abline_plot
from sklearn.metrics import mean_squared_error
# %matplotlib inline
sns.set_style('darkgrid')
pd.options.display.float_format = "{:,.2f}".format
import warnings
warnings.filterwarnings('ignore')
import matplotlib.ticker as mtick

# %%
# Getting the initial data and splitting into test and training sets in an 80:20 split
df = dc.test_split(
    dc.get_data('data/kc_house_data.csv')
)
X_train = df[0]
X_test = df[1]
y_train = df[2]
y_test = df[3]

# %%
# Data cleaning, dropping unused columns, feature engineering, dummy columns
X_train = dc.clean_it(df[0])
X_test = dc.clean_it(df[1])

# %%
X_train.columns
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'grade', 'sqft_above', 'yr_built',
#        'sqft_living15', 'sqft_lot15', 'has_been_renovated', 'ratio_15',
#        'years_old', 'condition_2', 'condition_3', 'condition_4',
#        'condition_5'],
#       dtype='object')

# %%
X_train.plot.scatter('sqft_living', 'grade')

# %%
X_train.plot.scatter('sqft_living', 'bedrooms')

# %%
X_train.plot.scatter('sqft_living', 'bathrooms')

# %%
X_train.plot.scatter('sqft_living', 'floors')

# %%
X_train.plot.scatter('sqft_living', 'waterfront')

# %%
X_train.plot.scatter('sqft_living', 'sqft_above')

# %%
X_train.plot.scatter('sqft_living', 'yr_built')

# %%
X_train.plot.scatter('sqft_living', 'years_old')

# %%
X_train.corr()
# Out:
#                       id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id                  1.00      0.00       0.01        -0.01     -0.14    0.02
# bedrooms            0.00      1.00       0.53         0.59      0.04    0.19
# bathrooms           0.01      0.53       1.00         0.75      0.09    0.51
# sqft_living        -0.01      0.59       0.75         1.00      0.18    0.36
# sqft_lot           -0.14      0.04       0.09         0.18      1.00   -0.00
# floors              0.02      0.19       0.51         0.36     -0.00    1.00
# waterfront         -0.00     -0.00       0.07         0.10      0.02    0.03
# grade               0.01      0.37       0.67         0.76      0.12    0.46
# sqft_above         -0.01      0.49       0.69         0.88      0.19    0.53
# yr_built            0.02      0.16       0.50         0.32      0.05    0.49
# sqft_living15      -0.01      0.41       0.57         0.76      0.15    0.29
# sqft_lot15         -0.14      0.03       0.09         0.18      0.73   -0.01
# has_been_renovated -0.01      0.02       0.05         0.05      0.01    0.01
# ratio_15           -0.01      0.43       0.45         0.56      0.09    0.20
# years_old          -0.02     -0.16      -0.50        -0.32     -0.05   -0.49
# condition_2        -0.01     -0.05      -0.08        -0.07      0.04   -0.05
# condition_3         0.03      0.01       0.19         0.10     -0.01    0.32
# condition_4        -0.02     -0.01      -0.16        -0.08      0.02   -0.26
# condition_5        -0.01      0.02      -0.04        -0.02     -0.02   -0.12
#
#                     waterfront  grade  sqft_above  yr_built  sqft_living15  \
# id                       -0.00   0.01       -0.01      0.02          -0.01
# bedrooms                 -0.00   0.37        0.49      0.16           0.41
# bathrooms                 0.07   0.67        0.69      0.50           0.57
# sqft_living               0.10   0.76        0.88      0.32           0.76
# sqft_lot                  0.02   0.12        0.19      0.05           0.15
# floors                    0.03   0.46        0.53      0.49           0.29
# waterfront                1.00   0.09        0.07     -0.02           0.09
# grade                     0.09   1.00        0.76      0.45           0.72
# sqft_above                0.07   0.76        1.00      0.42           0.73
# yr_built                 -0.02   0.45        0.42      1.00           0.33
# sqft_living15             0.09   0.72        0.73      0.33           1.00
# sqft_lot15                0.03   0.12        0.19      0.07           0.18
# has_been_renovated        0.08   0.02        0.02     -0.21           0.00
# ratio_15                  0.03   0.28        0.42      0.09          -0.06
# years_old                 0.02  -0.45       -0.42     -1.00          -0.33
# condition_2              -0.01  -0.09       -0.06     -0.07          -0.05
# condition_3              -0.02   0.20        0.19      0.39           0.12
# condition_4               0.01  -0.14       -0.14     -0.26          -0.08
# condition_5               0.01  -0.09       -0.09     -0.25          -0.06
#
#                     sqft_lot15  has_been_renovated  ratio_15  years_old  \
# id                       -0.14               -0.01     -0.01      -0.02
# bedrooms                  0.03                0.02      0.43      -0.16
# bathrooms                 0.09                0.05      0.45      -0.50
# sqft_living               0.18                0.05      0.56      -0.32
# sqft_lot                  0.73                0.01      0.09      -0.05
# floors                   -0.01                0.01      0.20      -0.49
# waterfront                0.03                0.08      0.03       0.02
# grade                     0.12                0.02      0.28      -0.45
# sqft_above                0.19                0.02      0.42      -0.42
# yr_built                  0.07               -0.21      0.09      -1.00
# sqft_living15             0.18                0.00     -0.06      -0.33
# sqft_lot15                1.00                0.01      0.07      -0.07
# has_been_renovated        0.01                1.00      0.09       0.21
# ratio_15                  0.07                0.09      1.00      -0.09
# years_old                -0.07                0.21     -0.09       1.00
# condition_2               0.02               -0.01     -0.05       0.07
# condition_3              -0.01                0.06      0.01      -0.39
# condition_4               0.02               -0.05     -0.03       0.26
# condition_5              -0.02               -0.03      0.05       0.25
#
#                     condition_2  condition_3  condition_4  condition_5
# id                        -0.01         0.03        -0.02        -0.01
# bedrooms                  -0.05         0.01        -0.01         0.02
# bathrooms                 -0.08         0.19        -0.16        -0.04
# sqft_living               -0.07         0.10        -0.08        -0.02
# sqft_lot                   0.04        -0.01         0.02        -0.02
# floors                    -0.05         0.32        -0.26        -0.12
# waterfront                -0.01        -0.02         0.01         0.01
# grade                     -0.09         0.20        -0.14        -0.09
# sqft_above                -0.06         0.19        -0.14        -0.09
# yr_built                  -0.07         0.39        -0.26        -0.25
# sqft_living15             -0.05         0.12        -0.08        -0.06
# sqft_lot15                 0.02        -0.01         0.02        -0.02
# has_been_renovated        -0.01         0.06        -0.05        -0.03
# ratio_15                  -0.05         0.01        -0.03         0.05
# years_old                  0.07        -0.39         0.26         0.25
# condition_2                1.00        -0.12        -0.05        -0.03
# condition_3               -0.12         1.00        -0.81        -0.40
# condition_4               -0.05        -0.81         1.00        -0.17
# condition_5               -0.03        -0.40        -0.17         1.00

# %%
abs(X_train.corr()) > 0.75
# Out:
#                        id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id                   True     False      False        False     False   False
# bedrooms            False      True      False        False     False   False
# bathrooms           False     False       True         True     False   False
# sqft_living         False     False       True         True     False   False
# sqft_lot            False     False      False        False      True   False
# floors              False     False      False        False     False    True
# waterfront          False     False      False        False     False   False
# grade               False     False      False         True     False   False
# sqft_above          False     False      False         True     False   False
# yr_built            False     False      False        False     False   False
# sqft_living15       False     False      False         True     False   False
# sqft_lot15          False     False      False        False     False   False
# has_been_renovated  False     False      False        False     False   False
# ratio_15            False     False      False        False     False   False
# years_old           False     False      False        False     False   False
# condition_2         False     False      False        False     False   False
# condition_3         False     False      False        False     False   False
# condition_4         False     False      False        False     False   False
# condition_5         False     False      False        False     False   False
#
#                     waterfront  grade  sqft_above  yr_built  sqft_living15  \
# id                       False  False       False     False          False
# bedrooms                 False  False       False     False          False
# bathrooms                False  False       False     False          False
# sqft_living              False   True        True     False           True
# sqft_lot                 False  False       False     False          False
# floors                   False  False       False     False          False
# waterfront                True  False       False     False          False
# grade                    False   True        True     False          False
# sqft_above               False   True        True     False          False
# yr_built                 False  False       False      True          False
# sqft_living15            False  False       False     False           True
# sqft_lot15               False  False       False     False          False
# has_been_renovated       False  False       False     False          False
# ratio_15                 False  False       False     False          False
# years_old                False  False       False      True          False
# condition_2              False  False       False     False          False
# condition_3              False  False       False     False          False
# condition_4              False  False       False     False          False
# condition_5              False  False       False     False          False
#
#                     sqft_lot15  has_been_renovated  ratio_15  years_old  \
# id                       False               False     False      False
# bedrooms                 False               False     False      False
# bathrooms                False               False     False      False
# sqft_living              False               False     False      False
# sqft_lot                 False               False     False      False
# floors                   False               False     False      False
# waterfront               False               False     False      False
# grade                    False               False     False      False
# sqft_above               False               False     False      False
# yr_built                 False               False     False       True
# sqft_living15            False               False     False      False
# sqft_lot15                True               False     False      False
# has_been_renovated       False                True     False      False
# ratio_15                 False               False      True      False
# years_old                False               False     False       True
# condition_2              False               False     False      False
# condition_3              False               False     False      False
# condition_4              False               False     False      False
# condition_5              False               False     False      False
#
#                     condition_2  condition_3  condition_4  condition_5
# id                        False        False        False        False
# bedrooms                  False        False        False        False
# bathrooms                 False        False        False        False
# sqft_living               False        False        False        False
# sqft_lot                  False        False        False        False
# floors                    False        False        False        False
# waterfront                False        False        False        False
# grade                     False        False        False        False
# sqft_above                False        False        False        False
# yr_built                  False        False        False        False
# sqft_living15             False        False        False        False
# sqft_lot15                False        False        False        False
# has_been_renovated        False        False        False        False
# ratio_15                  False        False        False        False
# years_old                 False        False        False        False
# condition_2                True        False        False        False
# condition_3               False         True         True        False
# condition_4               False         True         True        False
# condition_5               False        False        False         True

# %%
df=X_train.corr().abs().stack().reset_index().sort_values(0, ascending=False)

# zip the variable name columns (Which were only named level_0 and level_1 by default) in a new column named "pairs"
df['pairs'] = list(zip(df.level_0, df.level_1))

# set index to pairs
df.set_index(['pairs'], inplace = True)

#d rop level columns
df.drop(columns=['level_1', 'level_0'], inplace = True)

# rename correlation column as cc rather than 0
df.columns = ['cc']

# drop duplicates. This could be dangerous if you have variables perfectly correlated with variables other than themselves.
# for the sake of exercise, kept it in.
df.drop_duplicates(inplace=True)

# %%
df[(df.cc>.75) & (df.cc <1)]
# Out:
#                                cc
# pairs
# (yr_built, years_old)        1.00
# (sqft_above, sqft_living)    0.88
# (condition_3, condition_4)   0.81
# (grade, sqft_living)         0.76
# (sqft_living15, sqft_living) 0.76
# (grade, sqft_above)          0.76
# (sqft_living, bathrooms)     0.75

# %%
pd.plotting.scatter_matrix(X_train,figsize  = [9, 9]);
plt.show()

# %%
formula = "price ~ bathrooms + grade + waterfront + years_old + sqft_living"
model_6 = lrv.run_lr(formula, X_train, y_train)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.634
# Model:                            OLS   Adj. R-squared:                  0.634
# Method:                 Least Squares   F-statistic:                     5983.
# Date:                Wed, 21 Oct 2020   Prob (F-statistic):               0.00
# Time:                        21:09:22   Log-Likelihood:            -2.3744e+05
# No. Observations:               17277   AIC:                         4.749e+05
# Df Residuals:                   17271   BIC:                         4.749e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -1.133e+06   1.66e+04    -68.083      0.000   -1.17e+06    -1.1e+06
# bathrooms    4.215e+04   3758.818     11.214      0.000    3.48e+04    4.95e+04
# grade        1.406e+05   2396.632     58.647      0.000    1.36e+05    1.45e+05
# waterfront   8.199e+05   2.16e+04     37.954      0.000    7.78e+05    8.62e+05
# years_old    3872.5607     70.714     54.764      0.000    3733.955    4011.167
# sqft_living   150.1818      3.446     43.584      0.000     143.428     156.936
# ==============================================================================
# Omnibus:                    13530.688   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1061776.727
# Skew:                           3.186   Prob(JB):                         0.00
# Kurtosis:                      40.873   Cond. No.                     2.89e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.89e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_pred = model_6.predict(X_train)
model_6_rmse = np.sqrt(mean_squared_error(y_train, y_pred))
model_6_rmse
# Out:
# 225070.12225751637

# %%
formula = "price ~ waterfront + years_old + sqft_living"
model_6 = lrv.run_lr(formula, X_train, y_train)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.556
# Method:                 Least Squares   F-statistic:                     7201.
# Date:                Wed, 21 Oct 2020   Prob (F-statistic):               0.00
# Time:                        21:10:01   Log-Likelihood:            -2.3911e+05
# No. Observations:               17277   AIC:                         4.782e+05
# Df Residuals:                   17273   BIC:                         4.783e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -1.931e+05   6677.625    -28.912      0.000   -2.06e+05    -1.8e+05
# waterfront   8.692e+05   2.38e+04     36.550      0.000    8.23e+05    9.16e+05
# years_old    2250.0550     67.710     33.231      0.000    2117.337    2382.773
# sqft_living   296.6241      2.169    136.737      0.000     292.372     300.876
# ==============================================================================
# Omnibus:                    10637.623   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           374815.638
# Skew:                           2.407   Prob(JB):                         0.00
# Kurtosis:                      25.305   Cond. No.                     2.88e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.88e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_pred = model_6.predict(X_train)
model_6_rmse = np.sqrt(mean_squared_error(y_train, y_pred))
model_6_rmse
# Out:
# 244284.21076829467

# %%
formula = "price ~ bathrooms + grade + waterfront + years_old + ratio_15"
model_6 = lrv.run_lr(formula, X_train, y_train)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.594
# Model:                            OLS   Adj. R-squared:                  0.594
# Method:                 Least Squares   F-statistic:                     5060.
# Date:                Wed, 21 Oct 2020   Prob (F-statistic):               0.00
# Time:                        21:23:09   Log-Likelihood:            -2.3833e+05
# No. Observations:               17277   AIC:                         4.767e+05
# Df Residuals:                   17271   BIC:                         4.767e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.512e+06   1.54e+04    -97.937      0.000   -1.54e+06   -1.48e+06
# bathrooms   1.252e+05   3603.198     34.747      0.000    1.18e+05    1.32e+05
# grade       1.992e+05   2087.093     95.456      0.000    1.95e+05    2.03e+05
# waterfront  8.617e+05   2.27e+04     37.924      0.000    8.17e+05    9.06e+05
# years_old   4550.2752     73.395     61.997      0.000    4406.414    4694.136
# ratio_15    3.194e+04   6355.527      5.026      0.000    1.95e+04    4.44e+04
# ==============================================================================
# Omnibus:                    15119.423   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1649749.027
# Skew:                           3.714   Prob(JB):                         0.00
# Kurtosis:                      50.292   Cond. No.                         729.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_pred = model_6.predict(X_train)
model_6_rmse = np.sqrt(mean_squared_error(y_train, y_pred))
model_6_rmse
# Out:
# 236951.60963766123

# %%
formula = "price ~ bathrooms + grade + waterfront + years_old + bedrooms"
model_6 = lrv.run_lr(formula, X_train, y_train)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.594
# Model:                            OLS   Adj. R-squared:                  0.594
# Method:                 Least Squares   F-statistic:                     5048.
# Date:                Wed, 21 Oct 2020   Prob (F-statistic):               0.00
# Time:                        21:11:19   Log-Likelihood:            -2.3834e+05
# No. Observations:               17277   AIC:                         4.767e+05
# Df Residuals:                   17271   BIC:                         4.767e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.495e+06   1.55e+04    -96.377      0.000   -1.53e+06   -1.46e+06
# bathrooms   1.331e+05   3666.685     36.302      0.000    1.26e+05     1.4e+05
# grade       1.993e+05   2091.529     95.289      0.000    1.95e+05    2.03e+05
# waterfront  8.603e+05   2.28e+04     37.780      0.000    8.16e+05    9.05e+05
# years_old   4619.6621     73.158     63.146      0.000    4476.264    4763.060
# bedrooms    -989.9820   2392.327     -0.414      0.679   -5679.186    3699.222
# ==============================================================================
# Omnibus:                    15166.778   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1673871.411
# Skew:                           3.730   Prob(JB):                         0.00
# Kurtosis:                      50.640   Cond. No.                         731.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_pred = model_6.predict(X_train)
model_6_rmse = np.sqrt(mean_squared_error(y_train, y_pred))
model_6_rmse
# Out:
# 244284.21076829467

# %%
formula = "price ~ bedrooms + waterfront + years_old + sqft_living"
model_6 = lrv.run_lr(formula, X_train, y_train)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.569
# Model:                            OLS   Adj. R-squared:                  0.569
# Method:                 Least Squares   F-statistic:                     5696.
# Date:                Wed, 21 Oct 2020   Prob (F-statistic):               0.00
# Time:                        21:11:42   Log-Likelihood:            -2.3885e+05
# No. Observations:               17277   AIC:                         4.777e+05
# Df Residuals:                   17272   BIC:                         4.778e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    -6.97e+04   8498.127     -8.202      0.000   -8.64e+04    -5.3e+04
# bedrooms    -5.896e+04   2571.336    -22.931      0.000    -6.4e+04   -5.39e+04
# waterfront   8.258e+05   2.35e+04     35.133      0.000     7.8e+05    8.72e+05
# years_old    2309.0206     66.754     34.590      0.000    2178.177    2439.865
# sqft_living   331.5828      2.625    126.310      0.000     326.437     336.728
# ==============================================================================
# Omnibus:                    10243.189   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           336265.273
# Skew:                           2.297   Prob(JB):                         0.00
# Kurtosis:                      24.119   Cond. No.                     2.89e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.89e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_pred = model_6.predict(X_train)
model_6_rmse = np.sqrt(mean_squared_error(y_train, y_pred))
model_6_rmse
# Out:
# 244284.21076829467

# %%
formula = "price ~ bedrooms + has_been_renovated + waterfront + years_old + sqft_living"
model_6 = lrv.run_lr(formula, X_train, y_train)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.570
# Model:                            OLS   Adj. R-squared:                  0.570
# Method:                 Least Squares   F-statistic:                     4573.
# Date:                Wed, 21 Oct 2020   Prob (F-statistic):               0.00
# Time:                        21:20:02   Log-Likelihood:            -2.3884e+05
# No. Observations:               17277   AIC:                         4.777e+05
# Df Residuals:                   17271   BIC:                         4.777e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           -6.46e+04   8534.631     -7.569      0.000   -8.13e+04   -4.79e+04
# bedrooms           -5.872e+04   2569.198    -22.855      0.000   -6.38e+04   -5.37e+04
# has_been_renovated  6.107e+04   1.04e+04      5.853      0.000    4.06e+04    8.15e+04
# waterfront          8.179e+05   2.35e+04     34.771      0.000    7.72e+05    8.64e+05
# years_old           2215.8600     68.563     32.319      0.000    2081.470    2350.250
# sqft_living          329.9371      2.638    125.088      0.000     324.767     335.107
# ==============================================================================
# Omnibus:                    10216.853   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           334660.194
# Skew:                           2.289   Prob(JB):                         0.00
# Kurtosis:                      24.069   Cond. No.                     2.89e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.89e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_pred = model_6.predict(X_train)
model_6_rmse = np.sqrt(mean_squared_error(y_train, y_pred))
model_6_rmse
# Out:
# 239754.60159085537

# %%
formula = "price ~ bedrooms + has_been_renovated + ratio_15 + waterfront + years_old + sqft_living"
model_6 = lrv.run_lr(formula, X_train, y_train)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.585
# Model:                            OLS   Adj. R-squared:                  0.585
# Method:                 Least Squares   F-statistic:                     4052.
# Date:                Wed, 21 Oct 2020   Prob (F-statistic):               0.00
# Time:                        21:25:07   Log-Likelihood:            -2.3853e+05
# No. Observations:               17277   AIC:                         4.771e+05
# Df Residuals:                   17270   BIC:                         4.771e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           1.599e+04   8984.807      1.779      0.075   -1624.775    3.36e+04
# bedrooms           -4.973e+04   2549.703    -19.503      0.000   -5.47e+04   -4.47e+04
# has_been_renovated  7.397e+04   1.03e+04      7.207      0.000    5.39e+04    9.41e+04
# ratio_15           -1.741e+05   6974.106    -24.965      0.000   -1.88e+05    -1.6e+05
# waterfront          8.001e+05   2.31e+04     34.608      0.000    7.55e+05    8.45e+05
# years_old           2382.1851     67.689     35.193      0.000    2249.508    2514.862
# sqft_living          360.7680      2.871    125.676      0.000     355.141     366.395
# ==============================================================================
# Omnibus:                    10421.295   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           355002.656
# Skew:                           2.345   Prob(JB):                         0.00
# Kurtosis:                      24.706   Cond. No.                     2.89e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.89e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y_pred = model_6.predict(X_train)
model_6_rmse = np.sqrt(mean_squared_error(y_train, y_pred))
model_6_rmse
# Out:
# 239754.60159085537

# %%
final_model = model_6

# %%
mmean = final_model.resid.mean()
mmin = final_model.resid.min()
mmax = final_model.resid.max()
normalized_residuals = (final_model.resid - mmean)/(mmax - mmin)

t = final_model.fittedvalues
tmean = final_model.resid.mean()
tmin = final_model.resid.min()
tmax = final_model.resid.max()
normalized_predicted = (t - tmean)/(tmax - tmin)

# %%
fig, ax = plt.subplots(figsize = (14,8))
ax.set_xlabel('Normalized Residuals', fontsize = 14)
ax.set_ylabel('Frequency', fontsize = 14)
ax.set_title('Frequency of Normalized Residuals', fontsize = 24)
ax.set(xlim=(-0.25,.25))
sns.distplot(normalized_residuals, bins = 100);
fig.savefig('./images/residuals_hist.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize = (14,8))
ax.set_xlabel('Normalized Predicted Price', fontsize = 14)
ax.set_ylabel('Normalized Residuals', fontsize = 14)
ax.set_title('Residuals vs Predicted Values for Homoskedasticity', fontsize = 24)
sns.scatterplot(x = normalized_predicted, y = normalized_residuals);
fig.savefig('./images/homoskedasticity.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize = (12, 8))
stats.probplot(normalized_residuals, plot=plt)
ax.set_title('QQ Plot Probability of residuals', fontsize = 24)
ax.set_xlabel('Residuals', fontsize = 14)
ax.set_ylabel('Probability', fontsize = 14)
ax.legend(['Residuals','Normal line']);
fig.savefig('./images/qqplot.png', bbox_inches='tight')

# %%
X_train2 = X_train
X_train2['low_grade'] = [1 if x < 7 else 0 for x in X_train2['grade']]
X_train2['mid_grade'] = [1 if ((x >= 7) & (x < 10)) else 0 for x in X_train2['grade']]
X_train2['high_grade'] = [1 if x > 10 else 0 for x in X_train2['grade']]

# %%
formula = "price ~ bathrooms + low_grade + mid_grade + high_grade + waterfront + years_old"
model_6 = lrv.run_lr(formula, X_train2, y_train)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.543
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     3425.
# Date:                Thu, 22 Oct 2020   Prob (F-statistic):               0.00
# Time:                        08:57:08   Log-Likelihood:            -2.3935e+05
# No. Observations:               17277   AIC:                         4.787e+05
# Df Residuals:                   17270   BIC:                         4.788e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.296e+05   1.37e+04     24.055      0.000    3.03e+05    3.56e+05
# bathrooms   2.026e+05   3255.865     62.230      0.000    1.96e+05    2.09e+05
# low_grade  -5.588e+05   1.15e+04    -48.564      0.000   -5.81e+05   -5.36e+05
# mid_grade  -4.212e+05   8967.301    -46.969      0.000   -4.39e+05   -4.04e+05
# high_grade  4.854e+05   1.51e+04     32.187      0.000    4.56e+05    5.15e+05
# waterfront  8.372e+05   2.42e+04     34.651      0.000     7.9e+05    8.85e+05
# years_old   3466.2454     76.819     45.122      0.000    3315.672    3616.819
# ==============================================================================
# Omnibus:                    12266.705   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           719092.246
# Skew:                           2.809   Prob(JB):                         0.00
# Kurtosis:                      34.102   Cond. No.                         724.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
final_model = model_6

# %%
mmean = final_model.resid.mean()
mmin = final_model.resid.min()
mmax = final_model.resid.max()
normalized_residuals = (final_model.resid - mmean)/(mmax - mmin)

t = final_model.fittedvalues
tmean = final_model.resid.mean()
tmin = final_model.resid.min()
tmax = final_model.resid.max()
normalized_predicted = (t - tmean)/(tmax - tmin)

# %%
fig, ax = plt.subplots(figsize = (14,8))
ax.set_xlabel('Normalized Residuals', fontsize = 14)
ax.set_ylabel('Frequency', fontsize = 14)
ax.set_title('Frequency of Normalized Residuals', fontsize = 24)
ax.set(xlim=(-0.25,.25))
sns.distplot(normalized_residuals, bins = 100);
#fig.savefig('./images/residuals_hist.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize = (14,8))
ax.set_xlabel('Normalized Predicted Price', fontsize = 14)
ax.set_ylabel('Normalized Residuals', fontsize = 14)
ax.set_title('Residuals vs Predicted Values for Homoskedasticity', fontsize = 24)
sns.scatterplot(x = normalized_predicted, y = normalized_residuals);
fig.savefig('./images/homoskedasticity.png', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize = (12, 8))
stats.probplot(normalized_residuals, plot=plt)
ax.set_title('QQ Plot Probability of residuals', fontsize = 24)
ax.set_xlabel('Residuals', fontsize = 14)
ax.set_ylabel('Probability', fontsize = 14)
ax.legend(['Residuals','Normal line']);
fig.savefig('./images/qqplot.png', bbox_inches='tight')
