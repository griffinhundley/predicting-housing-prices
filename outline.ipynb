# %% [markdown]
# # Business Understanding
#
# ## Actor
#  - Real Estate Agency
#
# ## Goal/s
#  - Provide a price estimate for customers
#  - Quantify value of renovation
#
# ## MVP
#  - Isolate predicting housing prices based on current characteristics
#
# ## Above and beyond
#  - Renovations, (bang for buck)
#  - How many years after a renovation is it worth to do another

# %% [markdown]
# # For Monday
#    - Have you clearly defined your goal for your analysis?
#        - We want to be able predict sell prices for homes that will maximize the price for clients and commission for the agency
#
#
#    - What 3 (at least) specific questions will you be answering with your analysis?
#        1. Which features are the best predictors for price?
#        2. Do renovations impact the price?
#        3. Do surrounding home's size effect the selling price of houses? (in relation to the home)
#
#
#    - Have your thought about who your audience is and how they would use this information?
#        - Real Estate Agency, trying to get high commissions, looking at how features affect price.  When is it worth it to renovate.
#    - How does this help the goals of the business/organization?
#        - If you have an accurately priced house, it can be marketed more efficiently and sell better, and knowing when to renovate keeps a house valuable.

# %% [markdown]
# - Data Understanding
#    - How does your data help you answer the business question?
#        - Use regression models on past housing data to predict how different features affect the price of a home.
#    - How many observations does your dataset contain?
#        - 21597
#    - What is the distribution of your data?
#        - The price is a right-skewed distribution
#    - What data types do you have?
#        - int64, floats, objects

# %% [markdown]
# - Data Preparation
#    - Have you looked/dealt with missing values?
#        1. yr_renovated (potentially bin to 'has been renovated' and 'has not been renovated'
#        2. waterfront
#        3. view (potentially drop this column or impute 0 on NaNs)
#
#    - Have you done any data-type conversion?
#       - the data column needs to be converted to datetime
#       - sqft_basement needs to be converted to float/int, ? values as 0
#     - Does your data contain any outliers or non-sensical values?
#         nonsense values
#             - 0's in renovation
#             - ? in sqft_basement
#
#         outliers
#             - some prices are outliers (ie 7million mansion)
#
# - categorical - Potentially binning floors, waterfront, condition/grade, bedroom/bathrooms
# - continuous - renovation
# - new feature, combining sqft_lot and sqft_living to get ratio of living space to lot, and sqft_15

# %% [markdown]
# $$Price = \beta_0 + \beta_1{bathrooms} + \beta_2{sq ft} ... etc$$

# %% [markdown]
# ## Data
#  - King County, Washington Housing Data, 2014-2015

# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
data = pd.read_csv('./data/kc_house_data.csv')
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %%
data.sqft_basement.value_counts()
# Out:
# 0.0       12826
# ?           454
# 600.0       217
# 500.0       209
# 700.0       208
#           ...
# 2180.0        1
# 2196.0        1
# 666.0         1
# 295.0         1
# 176.0         1
# Name: sqft_basement, Length: 304, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
fig, ax = plt.subplots()
X = data.loc[data.price < 2000000].price
sns.distplot(X, ax = ax)

# %%
data.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.004176  0.276295 -0.002386   0.067282     0.110230  0.023143
# view           0.011592  0.395734  0.078523   0.186451     0.282532  0.075298
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...
